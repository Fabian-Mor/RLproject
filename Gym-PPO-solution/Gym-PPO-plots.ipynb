# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pickle
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import pylab as plt

# %% [markdown]
# ## Helper Functions

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %% [markdown]
# # PPO parameter dependency

# %% [markdown]
# ## clip for K=10

# %%
rewards10 = {}
env_name = "LunarLander-v2"
epsilons = [0.01,0.1,0.2,0.5,0.75]
k=10

for eps in epsilons:
    with open(f"./results/PPO_{env_name}-eps{eps}-k{k}-sNone-stat.pkl", 'rb') as f:
        data = pickle.load(f)
        rewards10[data["eps"]] = data["rewards"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 7
#       4 k=10
#       6 for eps in epsilons:
# ----> 7     with open(f"./results/PPO_{env_name}-eps{eps}-k{k}-sNone-stat.pkl", 'rb') as f:
#       8         data = pickle.load(f)
#       9         rewards10[data["eps"]] = data["rewards"]
#
# File ~\PycharmProjects\ReinforcementProject\.venv\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/PPO_LunarLander-v2-eps0.01-k10-sNone-stat.pkl'

# %%
fig=plt.figure(figsize=(6,3.8))
for eps,rew in rewards10.items():
    plt.plot(running_mean(rew,50),label=f"eps={eps}")
plt.legend()

# %%
fig.savefig(f"PPO_{env_name}_effect_clipping-k10.pdf")

# %% [markdown]
# ## restarts for k=10 and eps=0.2

# %%
rewards_s = {}
env_name = "LunarLander-v2"
eps = 0.2
k=10
ss=[0,1,2,3,4]

for s in ss:
    with open(f"./results/PPO_{env_name}-eps{eps}-k{k}-s{s}-stat.pkl", 'rb') as f:
        data = pickle.load(f)
        rewards_s[s] = data["rewards"]

# %%
fig=plt.figure(figsize=(6,3.8))
for s,rew in rewards_s.items():
    plt.plot(running_mean(rew,50),label=f"s={s}")
plt.legend()

# %%
fig.savefig(f"PPO_{env_name}_effect_restart-k10.pdf")

# %% [markdown]
# ## clip for K=4

# %%
rewards = {}
env_name = "LunarLander-v2"
epsilons = [0.01,0.1,0.2,0.5,0.75]
k=4

for eps in epsilons:
    with open(f"./results/PPO_{env_name}-eps{eps}-k{k}-sNone-stat.pkl", 'rb') as f:
        data = pickle.load(f)
        rewards[data["eps"]] = data["rewards"]

# %%
fig=plt.figure(figsize=(6,3.8))
for eps,rew in rewards.items():
    plt.plot(running_mean(rew,50),label=f"eps={eps}")
plt.legend()

# %%
fig.savefig(f"PPO_{env_name}_effect_clipping-k4.pdf")
